-- %%
SELECT TOP (1000) [id] ,[BigFiller]
FROM [Pool1].[dbo].[2767CD30-B43B-4DA8-8B11-69087857A59F]
-- Out:
-- (192 rows affected)
-- Total execution time: 00:00:00.5440239
-- <table><tr><th>id</th><th>BigFiller</th></tr><tr><td>1</td><td>x
